# %%
class A:

    def __init__(self):
        ...

    def search(self, q: str):
        ...

    def __getitem__(self, idx:int):
        return 3

# %%
a = A()

# %%
a[3]
# Out:
# 3

# %%
inputs = {"messages1": [1,2]}

# %%
if messages := inputs.get("messages", []):
    print(messages)
else:
    print("fail")
# Out:
# fail

# %%
tmp = inputs.get("messages", [])
if tmp:
    messages = tmp

# %%
messages
# Out:
# [1, 2]

# %%
def func(q: str):
    print(f"q: {q}")

# %%
a.search = func

# %%
a.search(1)
# Out:
# q: 1
