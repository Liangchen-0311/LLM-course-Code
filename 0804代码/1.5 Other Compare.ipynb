# %% [markdown]
# ## Introduction
#
#
# 多代理框架的洞察力在于它们模拟了一个由通才和专家组成的团队，他们合作完成某项任务。
#
# 这些代理基本上是循环，可以使用 LLM 输出来调用其他软件工具（如获取数据），并将结果反馈给 LLM，直到实现高级目标。
#
# 它们在以下情况下特别有用：
#
# - 不确定提前需要什么工具（即根据某些用户输入，可能需要执行 RAG、网络搜索或两者结合或其他操作）
# - LLM 可能需要尝试几次才能得到正确的答案，并且正确答案无需 LLM 验证（例如编写功能性可执行代码）。

# %% [markdown]
# ## [loveable.dev](https://lovable.dev)
#
# 原：https://gptengineer.app
#
# 一句需求到代码，可实时修改。

# %% [markdown]
# ![](lovable.png)

# %% [markdown]
# ## [gpt-engineer](https://github.com/gpt-engineer-org/gpt-engineer)
#
#
# Platform to experiment with the AI Software Engineer.
#
# Terminal based.
#
# NOTE: Very different from https://gptengineer.app
#
#
# 文档：https://gpt-engineer.readthedocs.io/en/latest/introduction.html

# %% [markdown]
# ```bash
# export OPENAI_API_BASE="https://api.moonshot.cn/v1"
# export OPENAI_API_KEY="sk-uC9JmkqkNAfDbotnsJODyIabgr1w8djaC9MqtcV4GZaUlPsY"
# export MODEL_NAME="moonshot-v1-128k"
# export LOCAL_MODEL=true
# ```

# %% [markdown]
# 步骤：
#
# - 创建文件夹和prompt（一句话）
# - 执行命令：`gpte --model $MODEL_NAME snake`
#
# 只有相关程序文件。

# %% [markdown]
# ![](gpte.png)

# %% [markdown]
# ## [AutoGPT](https://github.com/Significant-Gravitas/AutoGPT)
#
# AutoGPT is a powerful platform that allows you to create, deploy, and manage continuous AI agents that automate complex workflows.
#
#
# 创建、部署和管理AI 代理,从而实现复杂工作流的自动化。
#
# 文档：
#
#
# - https://docs.agpt.co/platform/getting-started/#checking-if-you-have-docker-docker-compose-installed
# - https://github.com/Significant-Gravitas/AutoGPT/blob/master/classic/FORGE-QUICKSTART.md
#
#
# 非常难以使用。

# %% [markdown]
# ## [CrewAI](https://github.com/crewAIInc/crewAI)
#
#
# Framework for orchestrating role-playing, autonomous AI agents. By fostering collaborative intelligence, CrewAI empowers agents to work together seamlessly, tackling complex tasks.
#
# 编排角色扮演、自主 AI 代理的框架。通过促进协作智能,CrewAI 使代理能够无缝协作,解决复杂的任务。

# %% [markdown]
# ## [Autogen](https://github.com/microsoft/autogen)
#
#
# AutoGen is an open-source framework for building AI agent systems. It simplifies the creation of event-driven, distributed, scalable, and resilient agentic applications. It allows you to quickly build systems where AI agents collaborate and perform tasks autonomously or with human oversight.
#
#
#
# 一个用于构建 AI 代理系统的开源框架。它简化了事件驱动、分布式、可扩展和弹性代理应用程序的创建。允许快速构建 AI 代理协作并自主执行任务或由人类监督的系统。

# %% [markdown]
# ## Diff
#
# - AutoGen, LangGraph, CrewAI
# - MetaGPT, loveable.dev
# - AutoGPT

# %% [markdown]
# ![](multi-agent-diff.png)

# %% [markdown]
# ## Reference
#
#
#
# - [Significant-Gravitas/AutoGPT: AutoGPT is the vision of accessible AI for everyone, to use and to build on. Our mission is to provide the tools, so that you can focus on what matters.](https://github.com/Significant-Gravitas/AutoGPT)
# - [microsoft/autogen: A programming framework for agentic AI 🤖](https://github.com/microsoft/autogen)
# - [crewAIInc/crewAI: Framework for orchestrating role-playing, autonomous AI agents. By fostering collaborative intelligence, CrewAI empowers agents to work together seamlessly, tackling complex tasks.](https://github.com/crewAIInc/crewAI)
# - [gpt-engineer-org/gpt-engineer: Platform to experiment with the AI Software Engineer. Terminal based. NOTE: Very different from https://gptengineer.app](https://github.com/gpt-engineer-org/gpt-engineer)
# - [reworkd/AgentGPT: 🤖 Assemble, configure, and deploy autonomous AI Agents in your browser.](https://github.com/reworkd/AgentGPT)
# - [yoheinakajima/babyagi](https://github.com/yoheinakajima/babyagi)
# - [Comparing multi-agent frameworks](https://blog.context.ai/comparing-leading-multi-agent-frameworks/)
