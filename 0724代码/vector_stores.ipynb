# %% [markdown]
# # LangChain 核心模块：Data Conneciton - Vector Stores
#
# 存储和搜索非结构化数据最常见的方法之一是将其嵌入并存储生成的嵌入向量，然后在查询时将非结构化查询进行嵌入，并检索与嵌入查询“最相似”的嵌入向量。
#
# 向量存储库负责为您存储已经过嵌入处理的数据并执行向量搜索。
#
#
# ![](https://python.langchain.com/assets/images/vector_stores-125d1675d58cfb46ce9054c9019fea72.jpg)
#
#
# 下面以 `Chroma` 为例展示功能和用法

# %%
# 安装必要依赖包
# !pip install chromadb
# Out:
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# Requirement already satisfied: chromadb in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (0.4.24)
# Requirement already satisfied: build>=1.0.3 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from chromadb) (1.2.2.post1)
# Requirement already satisfied: requests>=2.28 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from chromadb) (2.32.4)
# Requirement already satisfied: pydantic>=1.9 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from chromadb) (2.10.3)
# Requirement already satisfied: chroma-hnswlib==0.7.3 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from chromadb) (0.7.3)
# Requirement already satisfied: fastapi>=0.95.2 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from chromadb) (0.115.6)
# Requirement already satisfied: uvicorn[standard]>=0.18.3 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from chromadb) (0.32.1)
# Requirement already satisfied: numpy>=1.22.5 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from chromadb) (2.0.2)
# Requirement already satisfied: posthog>=2.4.0 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from chromadb) (3.7.4)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from chromadb) (4.12.2)
# Requirement already satisfied: pulsar-client>=3.1.0 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from chromadb) (3.5.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from chromadb) (1.17.1)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from chromadb) (1.28.2)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from chromadb) (1.28.2)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from chromadb) (0.49b2)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from chromadb) (1.28.2)
# Requirement already satisfied: tokenizers>=0.13.2 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from chromadb) (0.15.2)
# Requirement already satisfied: pypika>=0.48.9 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from chromadb) (4.66.1)
# Requirement already satisfied: overrides>=7.3.1 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from chromadb) (6.4.0)
# Requirement already satisfied: grpcio>=1.58.0 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from chromadb) (1.65.1)
# Requirement already satisfied: bcrypt>=4.0.1 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from chromadb) (4.2.1)
# Requirement already satisfied: typer>=0.9.0 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from chromadb) (0.15.1)
# Requirement already satisfied: kubernetes>=28.1.0 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from chromadb) (31.0.0)
# Requirement already satisfied: tenacity>=8.2.3 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from chromadb) (8.5.0)
# Requirement already satisfied: PyYAML>=6.0.0 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from chromadb) (6.0.1)
# Requirement already satisfied: mmh3>=4.0.1 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from chromadb) (5.0.1)
# Requirement already satisfied: orjson>=3.9.12 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from chromadb) (3.10.12)
# Requirement already satisfied: packaging>=19.1 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from build>=1.0.3->chromadb) (23.2)
# Requirement already satisfied: pyproject_hooks in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: importlib-metadata>=4.6 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from build>=1.0.3->chromadb) (8.1.0)
# Requirement already satisfied: tomli>=1.1.0 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from build>=1.0.3->chromadb) (2.0.2)
# Requirement already satisfied: starlette<0.42.0,>=0.40.0 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from fastapi>=0.95.2->chromadb) (0.41.3)
# Requirement already satisfied: certifi>=14.05.14 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (2024.2.2)
# Requirement already satisfied: six>=1.9.0 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (2.8.2)
# Requirement already satisfied: google-auth>=1.0.1 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (2.36.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests-oauthlib in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (1.26.18)
# Requirement already satisfied: durationpy>=0.7 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (0.9)
# Requirement already satisfied: coloredlogs in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb) (24.3.25)
# Requirement already satisfied: protobuf in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb) (5.29.1)
# Requirement already satisfied: sympy in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb) (1.12)
# Requirement already satisfied: deprecated>=1.2.6 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.15)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.66.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.28.2 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.28.2)
# Requirement already satisfied: opentelemetry-proto==1.28.2 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.28.2)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.49b2 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.49b2)
# Requirement already satisfied: opentelemetry-instrumentation==0.49b2 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.49b2)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.49b2 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.49b2)
# Requirement already satisfied: opentelemetry-util-http==0.49b2 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.49b2)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from opentelemetry-instrumentation==0.49b2->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.16.0)
# Requirement already satisfied: asgiref~=3.0 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from opentelemetry-instrumentation-asgi==0.49b2->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from posthog>=2.4.0->chromadb) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from pydantic>=1.9->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from pydantic>=1.9->chromadb) (2.27.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from requests>=2.28->chromadb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from requests>=2.28->chromadb) (3.6)
# Requirement already satisfied: huggingface_hub<1.0,>=0.16.4 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from tokenizers>=0.13.2->chromadb) (0.26.2)
# Requirement already satisfied: click>=8.0.0 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from typer>=0.9.0->chromadb) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from typer>=0.9.0->chromadb) (13.7.1)
# Requirement already satisfied: h11>=0.8 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.14.0)
# Requirement already satisfied: httptools>=0.6.3 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.4)
# Requirement already satisfied: python-dotenv>=0.13 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.0)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.0)
# Requirement already satisfied: websockets>=10.4 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (11.0.3)
# Requirement already satisfied: zipp>=3.1.0 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from importlib-resources->chromadb) (3.18.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.7.2)
# Requirement already satisfied: filelock in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.13.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2024.6.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from rich>=10.11.0->typer>=0.9.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from rich>=10.11.0->typer>=0.9.0->chromadb) (2.18.0)
# Requirement already satisfied: anyio<5,>=3.4.0 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from starlette<0.42.0,>=0.40.0->fastapi>=0.95.2->chromadb) (4.4.0)
# Requirement already satisfied: humanfriendly>=9.1 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: mpmath>=0.19 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from anyio<5,>=3.4.0->starlette<0.42.0,>=0.40.0->fastapi>=0.95.2->chromadb) (1.3.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from anyio<5,>=3.4.0->starlette<0.42.0,>=0.40.0->fastapi>=0.95.2->chromadb) (1.2.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.9.0->chromadb) (0.1.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /Users/superyaoyao/anaconda3/envs/xueyao/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.1)

# %% [markdown]
# ## 使用 Chroma 作为向量数据库，实现语义搜索

# %%
from langchain.document_loaders import TextLoader
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.text_splitter import CharacterTextSplitter
from langchain.vectorstores import Chroma
import os
os.environ['OPENAI_API_KEY'] = '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'
# 加载长文本
raw_documents = TextLoader('state_of_the_union.txt').load()

# %%
# 实例化文本分割器
text_splitter = CharacterTextSplitter(chunk_size=500, chunk_overlap=0)

# %%
# 分割文本
documents = text_splitter.split_documents(raw_documents)

# %%
documents
# Out:
# [Document(metadata={'source': 'state_of_the_union.txt'}, page_content='Madam Speaker, Madam Vice President, our First Lady and Second Gentleman. Members of Congress and the Cabinet. Justices of the Supreme Court. My fellow Americans.  \n\nLast year COVID-19 kept us apart. This year we are finally together again. \n\nTonight, we meet as Democrats Republicans and Independents. But most importantly as Americans. \n\nWith a duty to one another to the American people to the Constitution. \n\nAnd with an unwavering resolve that freedom will always triumph over tyranny.'),
#  Document(metadata={'source': 'state_of_the_union.txt'}, page_content='Six days ago, Russia’s Vladimir Putin sought to shake the foundations of the free world thinking he could make it bend to his menacing ways. But he badly miscalculated. \n\nHe thought he could roll into Ukraine and the world would roll over. Instead he met a wall of strength he never imagined. \n\nHe met the Ukrainian people. \n\nFrom President Zelenskyy to every Ukrainian, their fearlessness, their courage, their determination, inspires the world.'),
#  Document(metadata={'source': 'state_of_the_union.txt'}, page_content='Groups of citizens blocking tanks with their bodies. Everyone from students to retirees teachers turned soldiers defending their homeland. \n\nIn this struggle as President Zelenskyy said in his speech to the European Parliament “Light will win over darkness.” The Ukrainian Ambassador to the United States is here tonight.')]

# %%
embeddings_model = OpenAIEmbeddings()

# %% [markdown]
# ### 注意：Pandas 相关包首次导入错误后，再次执行即可正确导入

# %%
pip install numpy==1.26.4
# Out:
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# Collecting numpy==1.26.4
#   Downloading https://mirrors.aliyun.com/pypi/packages/ae/8c/ab03a7c25741f9ebc92684a20125fbc9fc1b8e1e700beb9197d750fdff88/numpy-1.26.4-cp39-cp39-macosx_11_0_arm64.whl (14.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 1.7 MB/s eta 0:00:0000:0100:01m
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gradio 4.22.0 requires pillow<11.0,>=8.0, but you have pillow 11.2.1 which is incompatible.
# langchain-community 0.3.10 requires langsmith<0.2.0,>=0.1.125, but you have langsmith 0.3.20 which is incompatible.
# nlopt 2.9.1 requires numpy<3,>=2, but you have numpy 1.26.4 which is incompatible.
# pandasai 2.4.2 requires pandas==1.5.3, but you have pandas 2.3.1 which is incompatible.
# pandasai 2.4.2 requires pillow<11.0.0,>=10.1.0, but you have pillow 11.2.1 which is incompatible.
# tensorboard 2.17.0 requires protobuf!=4.24.0,<5.0.0,>=3.19.6, but you have protobuf 5.29.1 which is incompatible.
# tensorflow 2.17.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 5.29.1 which is incompatible.
# unstructured 0.12.6 requires beautifulsoup4==4.12.3, but you have beautifulsoup4 4.13.4 which is incompatible.
# unstructured 0.12.6 requires lxml==5.1.0, but you have lxml 5.4.0 which is incompatible.
# unstructured 0.12.6 requires requests==2.31.0, but you have requests 2.32.4 which is incompatible.
# unstructured 0.12.6 requires tqdm==4.66.2, but you have tqdm 4.66.1 which is incompatible.
# unstructured 0.12.6 requires typing-extensions==4.9.0, but you have typing-extensions 4.12.2 which is incompatible.
# Successfully installed numpy-1.26.4
# Note: you may need to restart the kernel to use updated packages.

# %%
# 将分割后的文本，使用 OpenAI 嵌入模型获取嵌入向量，并存储在 Chroma 中
db = Chroma.from_documents(documents, embeddings_model)

# %% [markdown]
# #### 使用文本进行语义相似度搜索

# %%
query = "What did the president say about Ketanji Brown Jackson"
docs = db.similarity_search(query)
print(docs[0].page_content)
# Out:
# Number of requested results 4 is greater than number of elements in index 3, updating n_results = 3
# Madam Speaker, Madam Vice President, our First Lady and Second Gentleman. Members of Congress and the Cabinet. Justices of the Supreme Court. My fellow Americans.
#
# Last year COVID-19 kept us apart. This year we are finally together again.
#
# Tonight, we meet as Democrats Republicans and Independents. But most importantly as Americans.
#
# With a duty to one another to the American people to the Constitution.
#
# And with an unwavering resolve that freedom will always triumph over tyranny.

# %% [markdown]
# ### 使用嵌入向量进行语义相似度搜索

# %%
embedding_vector = embeddings_model.embed_query(query)
docs = db.similarity_search_by_vector(embedding_vector)
print(docs[0].page_content)
# Out:
# Number of requested results 4 is greater than number of elements in index 3, updating n_results = 3
# Madam Speaker, Madam Vice President, our First Lady and Second Gentleman. Members of Congress and the Cabinet. Justices of the Supreme Court. My fellow Americans.
#
# Last year COVID-19 kept us apart. This year we are finally together again.
#
# Tonight, we meet as Democrats Republicans and Independents. But most importantly as Americans.
#
# With a duty to one another to the American people to the Constitution.
#
# And with an unwavering resolve that freedom will always triumph over tyranny.
